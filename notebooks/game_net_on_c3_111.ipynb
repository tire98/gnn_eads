# %% [markdown]
# # Notebook for assessing the performance of GAME-Net on the C3 dataset

# %%
import warnings
warnings.filterwarnings('ignore')
import torch
import numpy as np
import os
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
# from gnn_eads.models import MODELSPATH
from gnn_eads.data import DATAPATH
from gnn_eads.core.process_ase_db_to_PyG_dataset import load_FG_dataset, families
from gnn_eads.core.functions_data_extraction import get_fragment_energy
from gnn_eads.core.nets import PreTrainedModel
from ase.db import connect
from ase.atoms import Atoms
from ase.visualize import view
from torch_geometric.loader import DataLoader
import plotly.offline
from sklearn.decomposition import PCA
plotly.offline.init_notebook_mode()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/trenningholtz/teklahome/Project/gnn_eads/notebooks/game_net_on_c3_111.ipynb Cell 2 in 1
#       <a href='vscode-notebook-cell://ssh-remote%2Bremote-p40/home/trenningholtz/teklahome/Project/gnn_eads/notebooks/game_net_on_c3_111.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> import plotly.express as px
#       <a href='vscode-notebook-cell://ssh-remote%2Bremote-p40/home/trenningholtz/teklahome/Project/gnn_eads/notebooks/game_net_on_c3_111.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> # from gnn_eads.models import MODELSPATH
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bremote-p40/home/trenningholtz/teklahome/Project/gnn_eads/notebooks/game_net_on_c3_111.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> from gnn_eads.data import DATAPATH
#      <a href='vscode-notebook-cell://ssh-remote%2Bremote-p40/home/trenningholtz/teklahome/Project/gnn_eads/notebooks/game_net_on_c3_111.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> from gnn_eads.core.process_ase_db_to_PyG_dataset import load_FG_dataset, families
#      <a href='vscode-notebook-cell://ssh-remote%2Bremote-p40/home/trenningholtz/teklahome/Project/gnn_eads/notebooks/game_net_on_c3_111.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a> from gnn_eads.core.functions_data_extraction import get_fragment_energy
#
# ModuleNotFoundError: No module named 'gnn_eads.data'

# %% [markdown]
# # Load Model

# %%
model_dir = os.path.join(MODELSPATH, "GAME_NET/")
model = PreTrainedModel(model_dir)

# %% [markdown]
# # Load C3 test set

# %%
families = ["propylene_111"]
path = os.path.join(DATAPATH, "propylene_test")
c3_loader =  load_FG_dataset(root=path,                                 database="propylene_c3_cu111_database.db",
                                            second_order=False, scale_factor=1.5, tolerance=.50, edge_features=False, ring_features=False,
                                            aromatic_features=False, radical_features=False, relax=False, num_el=False,
                                            family=families)
# Out:
# fam:  propylene_111
# [FGGraphDataset_Feat(357)]

# %% [markdown]
# ## Create dataloader

# %%
c3_dataloader = DataLoader(c3_loader, batch_size=16, shuffle=False)
print(len(c3_dataloader.dataset))
# Out:
# 1

# %% [markdown]
# # Evaluate C3 test set

# %%
formula, data_id, category, true, pred = [], [], [], [], []
for i in range(len(c3_dataloader.dataset)):
    for graph in c3_dataloader.dataset[i]:
        formula.append(graph.formula)
        data_id.append(graph.id.item())
        category.append(graph.family)
        true.append(graph.ener.item())

    for batch in c3_dataloader.dataset[i]:
        with torch.no_grad():
            y = model.model(batch) * model.std + model.mean
            for i in range(len(y)):
                pred.append(y[i].item())
# Out:
# <class 'float'>

# %% [markdown]
# ## Create dataframe with predictions

# %%
df_c3_dataset = pd.DataFrame({'formula': formula, 'data_id': data_id, 'family': category, 'true': true, 'pred': pred})
df_c3_dataset["error"] = df_c3_dataset["true"] - df_c3_dataset["pred"]
df_c3_dataset["abs_error"] = np.abs(df_c3_dataset["error"])
df_c3_dataset
# Out:
#        formula  data_id         family       true       pred     error  \
# 0    Cu5C3H3O3        1  propylene_111 -57.414040 -57.297058 -0.116982
# 1    Cu5C3H3O2        2  propylene_111 -50.023262 -50.026581  0.003319
# 2     Cu4C3H2O        3  propylene_111 -39.781322 -40.038677  0.257355
# 3      Cu4C3H2        4  propylene_111 -32.264820 -33.349289  1.084469
# 4      Cu6C3H4        5  propylene_111 -39.215176 -40.287033  1.071857
# ..         ...      ...            ...        ...        ...       ...
# 352  Cu4C3H5O2      353  propylene_111 -59.469173 -58.421738 -1.047436
# 353  Cu6C3H4O2      354  propylene_111 -53.106983 -54.286736  1.179752
# 354  Cu4C3H6O3      355  propylene_111 -69.362976 -69.255493 -0.107483
# 355  Cu5C3H3O2      356  propylene_111 -50.902348 -50.120155 -0.782192
# 356  Cu2C3H6O2      357  propylene_111 -63.788280 -63.527897 -0.260384
#
#      abs_error
# 0     0.116982
# 1     0.003319
# 2     0.257355
# 3     1.084469
# 4     1.071857
# ..         ...
# 352   1.047436
# 353   1.179752
# 354   0.107483
# 355   0.782192
# 356   0.260384
#
# [357 rows x 7 columns]

# %% [markdown]
# ## Get Information From Database

# %%
ids = df_c3_dataset["data_id"]
with connect(os.path.join(DATAPATH, "propylene_test/raw", "propylene_c3_cu111_database_15_50.db")) as conn:
    for id in ids:
        row = conn.get(id)
        atoms = row.toatoms()
        atoms = atoms.todict()
        metal = row.metal
        n_O = row.o_atoms
        n_C = row.c_atoms
        n_H = row.h_atoms
        try:
            n_N = row.n_atoms
            n_S = row.s_atoms
        except:
            n_N = 0
            n_S = 0
        df_c3_dataset.loc[df_c3_dataset["data_id"] == id, ["metal", "n_O", "n_C", "n_H", "n_N", "n_S",]] = [metal, n_O, n_C, n_H, n_N, n_S,]
        df_c3_dataset.loc[df_c3_dataset["data_id"] == id, "atoms_ob"] = [atoms]

# %% [markdown]
# ## Get $E_{ads}$ by substracting gas phase energy of adsorbate

# %%
df_game_net = df_c3_dataset.assign(mae_metal = df_c3_dataset.groupby(['metal'])['abs_error'].transform('mean'))
df_game_net['e_frag'] = df_gnn_eads.apply(lambda x: get_fragment_energy([x['n_C'], x['n_H'], x['n_O'], x['n_N'], x['n_S']]), axis=1)
df_game_net['true_scaled'] = df_game_net['true'] - df_game_net['e_frag']
df_game_net['pred_scaled'] = df_game_net['pred'] - df_game_net['e_frag']
# Out:
#        formula  data_id         family       true       pred     error  \
# 337  Cu7C3H6O2      338  propylene_111 -62.196178 -62.221443  0.025265
# 338  Cu6C3H6O3      339  propylene_111 -69.221100 -69.235733  0.014633
# 339  Cu5C3H6O2      340  propylene_111 -61.593639 -61.603863  0.010223
# 340  Cu7C3H3O2      341  propylene_111 -50.113289 -50.537949  0.424660
# 341   Cu6C3H3O      342  propylene_111 -43.058178 -42.764397 -0.293781
# 342  Cu9C3H3O2      343  propylene_111 -51.324703 -49.505154 -1.819550
# 343   Cu6C3H3O      344  propylene_111 -43.607922 -43.203491 -0.404430
# 344  Cu6C3H3O2      345  propylene_111 -50.355511 -49.874825 -0.480686
# 345   Cu5C3H3O      346  propylene_111 -43.733509 -43.740005  0.006496
# 346  Cu6C3H3O2      347  propylene_111 -49.959259 -49.423416 -0.535843
# 347    Cu4C3HO      348  propylene_111 -36.053425 -36.379211  0.325787
# 348   Cu3C3H6O      349  propylene_111 -56.092255 -56.265869  0.173615
# 349   Cu5C3H3O      350  propylene_111 -43.230412 -42.906410 -0.324001
# 350  Cu4C3H7O3      351  propylene_111 -73.676048 -73.499146 -0.176903
# 351  Cu5C3H4O2      352  propylene_111 -53.867405 -54.661476  0.794071
# 352  Cu4C3H5O2      353  propylene_111 -59.469173 -58.421738 -1.047436
# 353  Cu6C3H4O2      354  propylene_111 -53.106983 -54.286736  1.179752
# 354  Cu4C3H6O3      355  propylene_111 -69.362976 -69.255493 -0.107483
# 355  Cu5C3H3O2      356  propylene_111 -50.902348 -50.120155 -0.782192
# 356  Cu2C3H6O2      357  propylene_111 -63.788280 -63.527897 -0.260384
#
#      abs_error metal  n_O  n_C  n_H  n_N  n_S  \
# 337   0.025265    Cu  2.0  3.0  6.0  0.0  0.0
# 338   0.014633    Cu  3.0  3.0  6.0  0.0  0.0
# 339   0.010223    Cu  2.0  3.0  6.0  0.0  0.0
# 340   0.424660    Cu  2.0  3.0  3.0  0.0  0.0
# 341   0.293781    Cu  1.0  3.0  3.0  0.0  0.0
# 342   1.819550    Cu  2.0  3.0  3.0  0.0  0.0
# 343   0.404430    Cu  1.0  3.0  3.0  0.0  0.0
# 344   0.480686    Cu  2.0  3.0  3.0  0.0  0.0
# 345   0.006496    Cu  1.0  3.0  3.0  0.0  0.0
# 346   0.535843    Cu  2.0  3.0  3.0  0.0  0.0
# 347   0.325787    Cu  1.0  3.0  1.0  0.0  0.0
# 348   0.173615    Cu  1.0  3.0  6.0  0.0  0.0
# 349   0.324001    Cu  1.0  3.0  3.0  0.0  0.0
# 350   0.176903    Cu  3.0  3.0  7.0  0.0  0.0
# 351   0.794071    Cu  2.0  3.0  4.0  0.0  0.0
# 352   1.047436    Cu  2.0  3.0  5.0  0.0  0.0
# 353   1.179752    Cu  2.0  3.0  4.0  0.0  0.0
# 354   0.107483    Cu  3.0  3.0  6.0  0.0  0.0
# 355   0.782192    Cu  2.0  3.0  3.0  0.0  0.0
# 356   0.260384    Cu  2.0  3.0  6.0  0.0  0.0
#
#                                               atoms_ob  mae_metal     e_frag  \
# 337  {'numbers': [29, 29, 29, 29, 29, 29, 29, 29, 2...   0.551729 -59.376141
# 338  {'numbers': [29, 29, 29, 29, 29, 29, 29, 29, 2...   0.551729 -66.828518
# 339  {'numbers': [29, 29, 29, 29, 29, 29, 29, 29, 2...   0.551729 -59.376141
# 340  {'numbers': [29, 29, 29, 29, 29, 29, 29, 29, 2...   0.551729 -49.226548
# 341  {'numbers': [29, 29, 29, 29, 29, 29, 29, 29, 2...   0.551729 -41.774170
# 342  {'numbers': [29, 29, 29, 29, 29, 29, 29, 29, 2...   0.551729 -49.226548
# 343  {'numbers': [29, 29, 29, 29, 29, 29, 29, 29, 2...   0.551729 -41.774170
# 344  {'numbers': [29, 29, 29, 29, 29, 29, 29, 29, 2...   0.551729 -49.226548
# 345  {'numbers': [29, 29, 29, 29, 29, 29, 29, 29, 2...   0.551729 -41.774170
# 346  {'numbers': [29, 29, 29, 29, 29, 29, 29, 29, 2...   0.551729 -49.226548
# 347  {'numbers': [29, 29, 29, 29, 29, 29, 29, 29, 2...   0.551729 -35.007775
# 348  {'numbers': [29, 29, 29, 29, 29, 29, 29, 29, 2...   0.551729 -51.923763
# 349  {'numbers': [29, 29, 29, 29, 29, 29, 29, 29, 2...   0.551729 -41.774170
# 350  {'numbers': [29, 29, 29, 29, 29, 29, 29, 29, 2...   0.551729 -70.211716
# 351  {'numbers': [29, 29, 29, 29, 29, 29, 29, 29, 2...   0.551729 -52.609746
# 352  {'numbers': [29, 29, 29, 29, 29, 29, 29, 29, 2...   0.551729 -55.992943
# 353  {'numbers': [29, 29, 29, 29, 29, 29, 29, 29, 2...   0.551729 -52.609746
# 354  {'numbers': [29, 29, 29, 29, 29, 29, 29, 29, 2...   0.551729 -66.828518
# 355  {'numbers': [29, 29, 29, 29, 29, 29, 29, 29, 2...   0.551729 -49.226548
# 356  {'numbers': [29, 29, 29, 29, 29, 29, 29, 29, 2...   0.551729 -59.376141
#
#      true_scaled  pred_scaled
# 337    -2.820038    -2.845303
# 338    -2.392581    -2.407215
# 339    -2.217499    -2.227722
# 340    -0.886741    -1.311400
# 341    -1.284008    -0.990226
# 342    -2.098155    -0.278605
# 343    -1.833751    -1.429321
# 344    -1.128962    -0.648276
# 345    -1.959339    -1.965835
# 346    -0.732711    -0.196868
# 347    -1.045649    -1.371436
# 348    -4.168492    -4.342107
# 349    -1.456241    -1.132240
# 350    -3.464332    -3.287430
# 351    -1.257659    -2.051730
# 352    -3.476230    -2.428795
# 353    -0.497238    -1.676990
# 354    -2.534458    -2.426975
# 355    -1.675799    -0.893607
# 356    -4.412140    -4.151756

# %% [markdown]
# ## Get prediction metric

# %%
MAE = df_c3_dataset["abs_error"].mean()
RMSE = np.sqrt((df_c3_dataset["error"]**2).mean())
R2 = 1 - (df_game_net["error"]**2).sum() / ((df_game_net["true_scaled"] - df_game_net["true_scaled"].mean())**2).sum()
MDAE = df_c3_dataset["abs_error"].median()

# print statistics

print("MAE: {:.2f} eV".format(MAE))
print("RMSE: {:.2f} eV".format(RMSE))
print("R2: {:.2f}".format(R2))
print("MDAE: {:.2f} eV".format(MDAE))
# Out:
# MAE: 0.55 eV
# RMSE: 0.73 eV
# R2: 0.67
# MDAE: 0.42 eV

# %% [markdown]
# # Create interactive scatter plot

# %%
from gnn_eads.core.constants import rgb_colors
from plotly.express import colors
import plotly.figure_factory as ff
colors = colors.qualitative.Light24_r
metals = df_game_net["metal"].unique() 
colour_dict = dict(zip(metals, colors))

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=[df_game_net["true_scaled"].min() - 0.25, df_game_net["true_scaled"].max() + 0.25], y=[df_game_net["true_scaled"].min() - 0.25, df_game_net["true_scaled"].max() + .25], mode='lines', name='Parity line'))
                         
fig.add_trace(go.Scatter(x=df_game_net["true_scaled"], y=df_game_net["pred_scaled"], customdata=df_game_net["formula"],
                             hovertemplate='DFT: %{x:.2f} eV<br>Prediction: %{y:.2f} eV<br>' + 
                             'Formula: %{customdata}<extra></extra>', mode='markers', marker=dict(size=12, line=dict(width=2, color="black"), color=colour_dict["Cu"]), opacity=0.6))

fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='black',  zeroline=True, zerolinewidth=2, zerolinecolor='black', mirror=True)

fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='black', zeroline=True, zerolinewidth=2, zerolinecolor='black', mirror=True)

fig.update_coloraxes(colorbar=dict(title="Metal", titleside="right", titlefont=dict(size=12), tickfont=dict(size=12), lenmode="pixels", len=200))


fig.update_layout(title='Parity plot for fragment groups', xaxis_title='DFT Energy / eV', yaxis_title=r'$E_\text{ads}^\text{GNN} / eV$',
                  autosize=True, width=1200, height=1200
                  , margin=dict(l=50, r=50, b=100, t=100, pad=4), grid=dict(rows=1, columns=1, pattern="independent"), 
                  paper_bgcolor="white", plot_bgcolor="white",
                  )
# add text box with MAE and RMSE
fig.add_annotation(x=0.05, y=0.95, xref="paper", yref="paper",
                   text="MAE: " + str(round(df_game_net["abs_error"].mean(), 2)) + " eV\
                   <br>RMSE: " + str(RMSE.round(2)) + "eV \
                   <br>R2: " + str(R2.round(2)) + " \
                   <br>MDAE: " + str(MDAE.round(2)) + "eV ",
                   align="left", showarrow=False, font=dict(size=12, color="black", family="Arial"),
                   bordercolor="black", borderwidth=1, borderpad=2, bgcolor="white", opacity=0.8)

fig.show()
# Out:
# <div>                            <div id="6ba33407-41b7-432b-99c7-eb9d20408e30" class="plotly-graph-div" style="height:1200px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6ba33407-41b7-432b-99c7-eb9d20408e30")) {                    Plotly.newPlot(                        "6ba33407-41b7-432b-99c7-eb9d20408e30",                        [{"mode":"lines","name":"Parity line","x":[-6.417169588232412,1.319119852968754],"y":[-6.417169588232412,1.319119852968754],"type":"scatter"},{"customdata":["Cu5C3H3O3","Cu5C3H3O2","Cu4C3H2O","Cu4C3H2","Cu6C3H4","Cu4C3H4O2","Cu5C3H3O3","Cu6C3H3O3","Cu7C3H3O2","Cu4C3H3O2","Cu7C3H3O3","Cu5C3H4O2","Cu6C3H4O2","Cu3C3H4","Cu3C3H3O2","Cu6C3H4O2","Cu6C3H2O","Cu4C3H","Cu3C3O","Cu5C3H2O","Cu7C3H2O","Cu4C3H4O2","Cu5C3H4O2","Cu4C3H4O","Cu5C3H4O2","Cu3C3H3O3","Cu6C3H2","Cu6C3H4O","Cu4C3H2O","Cu4C3H4O","Cu8C3H3O3","Cu5C3H4","Cu3C3H4O2","Cu6C3H4O","Cu4C3H4O","Cu3C3H4O","Cu5C3H4O3","Cu4C3H4O","Cu7C3H4O3","Cu6C3H4O2","Cu3C3H5","Cu5C3H3O3","Cu6C3H4O","Cu7C3H4O","Cu4C3H3O2","Cu8C3H4O2","Cu6C3H3O3","Cu5C3H2O2","Cu5C3H4O2","Cu4C3HO","Cu7C3H3O3","Cu5C3H4O","Cu5C3H4O3","Cu4C3H4O2","Cu6C3H3O3","Cu7C3H2O2","Cu2C3H4O2","Cu6C3H4O2","Cu6C3H2O2","Cu5C3H4O2","Cu3C3H2O2","Cu5C3H2O","Cu6C3H4O2","Cu4C3H4O2","Cu7C3HO","Cu4C3H2O2","Cu7C3H4O2","Cu6C3H4O3","Cu3C3H4O3","Cu7C3H4O3","Cu3C3H5O","Cu6C3H2O2","Cu5C3H4O2","CuC3O2","Cu6C3H5O","Cu5C3H5O2","Cu6C3H5O","Cu6C3H4O2","Cu6C3H4O2","Cu8C3H4O3","Cu4C3H5O2","Cu3C3HO2","Cu5C3H2O2","Cu4C3HO2","Cu7C3H4O3","Cu4C3H5O","Cu5C3H2O2","Cu6C3H5O","Cu8C3H2O3","Cu4C3H2O2","Cu8C3H4O2","Cu6C3H5O2","Cu6C3H5","Cu5C3H4O2","Cu7C3H4O3","Cu6C3H2O2","Cu5C3H5O","Cu5C3H2O2","Cu6C3H4O3","Cu3C3H5O2","Cu2C3H5O","Cu6C3H5O2","Cu4C3H4O3","Cu3C3H5O","Cu5C3H4O2","Cu5C3H2O2","Cu6C3H2O2","Cu7C3O2","Cu7C3H5O2","Cu5C3H5","Cu6C3H4O2","Cu9C3H2O3","Cu7C3H5O2","Cu6C3H5O2","Cu7C3H5O2","Cu6C3H5O2","Cu5C3H5O2","Cu4C3H2O2","Cu6C3H4O3","Cu6C3H5O","Cu4C3H5O","Cu4C3H5O2","Cu6C3H5O","Cu4C3H6","Cu5C3H5O2","Cu5C3H5O2","Cu6C3H5O2","Cu7C3H5O","Cu2C3H2O2","Cu3C3H4O3","Cu4C3H5O","Cu6C3H5O3","Cu4C3H2O3","Cu6C3H4O3","Cu6C3H5O","Cu6C3H5O2","Cu5C3H6O","Cu5C3H5O","Cu3C3H5O2","Cu5C3H5O2","Cu5C3H5O2","Cu5C3H5O","Cu6C3H5","Cu5C3H4O","Cu5C3H6","Cu8C3","Cu5C3H2O3","Cu6C3H5O3","Cu6C3H4O","Cu6C3H6","Cu7C3H5O2","Cu5C3H6O","Cu6C3H5O","Cu8C3H5O3","Cu5C3H5O3","Cu5C3H5O3","Cu7C3H2O3","Cu4C3H6O2","Cu5C3H5O2","Cu4C3H5O3","Cu6C3H4O","Cu5C3H2O3","Cu3C3H6O","Cu4C3H3O","Cu2C3H6O2","Cu4C3H5O2","Cu6C3H5O2","Cu6C3HO2","Cu3C3H5O2","Cu7C3H5O2","Cu7C3H5O3","Cu6C3H5O2","Cu3C3H6O","Cu5C3H5O3","Cu5C3H3","Cu7C3H6O2","Cu5C3H6O","Cu5C3H6O2","Cu4C3H4O","Cu5C3H7O2","Cu4C3H3","Cu5C3H3O2","Cu5C3H7O3","Cu5C3H5O","Cu8C3H5O2","Cu5C3H8O2","Cu5C3H4O2","Cu5C3H4O3","Cu5C3H5O2","Cu4C3H7O","Cu7C3H5O","Cu3C3H8","Cu7C3H5O2","Cu3C3H2","Cu5C3H7O","Cu5C3H5O","Cu6C3H6O","Cu5C3H4","Cu6C3H2O2","Cu6C3H2O2","Cu5C3H6O","Cu3C3H8O2","Cu5C3H2O3","Cu5C3H6O","Cu4C3H5","Cu4C3H3O2","Cu4C3H3O","Cu3C3HO2","Cu4C3H7O2","Cu6C3H4O2","Cu5C3H4O","Cu4C3H2O2","Cu4C3H3O2","Cu7C3H6O3","Cu8C3H5O3","Cu5C3H6O","Cu7C3H6O2","Cu7C3H7O3","Cu7C3HO3","Cu5C3H5O2","Cu8C3H6O2","Cu8C3H6O3","Cu5C3H4O2","Cu5C3H3O2","Cu3C3H6O","Cu4C3H8O3","Cu8C3H4O2","Cu5C3H3O3","Cu5C3H2","Cu7C3H5O3","Cu7C3H3O2","Cu8C3H3O3","Cu7C3H4O3","CuC3H6O","Cu5C3H3O2","Cu7C3H4O2","Cu6C3H2O3","Cu7C3H4O3","Cu3C3H7O","Cu4C3H4O","Cu2C3H8O","Cu4C3H7O2","Cu6C3H3O2","Cu5C3H7","Cu3C3H3O2","Cu9C3H5O3","Cu4C3H3O","Cu4C3H2O2","Cu4C3H4O","Cu8C3H3O","Cu5C3H7O2","Cu7C3H4O2","Cu4C3H3O2","Cu7C3H6O","Cu6C3H5O3","Cu4C3H4O2","Cu3C3HO2","Cu5C3H3O3","Cu4C3H6O2","Cu7C3H6O2","Cu6C3H3O","Cu4C3H6O3","Cu4C3H7O2","Cu5C3H7O","Cu4C3H4","Cu5C3O3","Cu7C3H3O","Cu4C3H3O2","Cu6C3H3O2","Cu7C3H3O3","Cu2C3H6O2","Cu5C3H6O2","Cu7C3H6O2","Cu5C3H6O","Cu5C3H7O","Cu6C3H6O3","Cu4C3H3","Cu5C3H6O2","Cu4C3H6","Cu3C3H3","Cu6C3H5O3","Cu4C3H3O","Cu4C3H3O2","Cu6C3H6O3","Cu4C3H2O2","Cu7C3H3O2","Cu4C3H3O3","Cu7C3HO3", ...

# %% [markdown]
# # Error distribution plot

# %%
fig = ff.create_distplot([df_game_net["error"]], ["Error_C3", "Error_rad"], bin_size=0.05, curve_type="normal", colors=["#2E91E5"], show_rug=False, show_hist=False)

fig.update_layout(title_text=r'$ \text{Distribution of } E_{\text{ads}} \text{energies for open-shell molecules}$', xaxis_title=r"$E_{\text{ads}} \text{/ eV}$", yaxis_title="Density")

fig.update_layout(width=576, height=576, margin=dict(l=50, r=50, b=50, t=50, pad=4), paper_bgcolor="white", plot_bgcolor="white", font=dict(size=12, color="black", family="Arial"))

fig.update_xaxes(showgrid=True, zeroline=False, showline=True, linewidth=2, linecolor='black', mirror=False, tickangle=0, tickfont=dict(size=12, color="black", family="Arial"), gridcolor="black", gridwidth=1,
                 title=dict(font=dict(size=16, color="black", family="Arial")), range=[-2, 2.5])

fig.update_yaxes(showgrid=True, gridcolor="black", zeroline=False, showline=True, linewidth=2, linecolor='black', mirror=True,
                 title=dict(font=dict(size=16, color="black", family="Arial", )
                            ))

fig.update_traces(line=dict(width=3))
# add vertical line for mean and median deviation
fig.add_shape(type="line", x0=df_game_net["error"].mean(), y0=-.05, x1=df_game_net["error"].mean(), y1=0.75, line=dict(color="black", width=2, dash="dash"))

fig.add_shape(type="line", x0=df_game_net["error"].median(), y0=-.05, x1=df_game_net["error"].median(), y1=0.75, line=dict(color="red", width=2, dash="dash"))

fig.show()
# Out:
# <div>                            <div id="9f13a150-413f-47a0-b371-b1cbd2dfda9c" class="plotly-graph-div" style="height:576px; width:576px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9f13a150-413f-47a0-b371-b1cbd2dfda9c")) {                    Plotly.newPlot(                        "9f13a150-413f-47a0-b371-b1cbd2dfda9c",                        [{"legendgroup":"Error_C3","marker":{"color":"#2E91E5"},"mode":"lines","name":"Error_C3","showlegend":true,"x":[-1.819549560546875,-1.8109748077392578,-1.8024000549316406,-1.7938253021240234,-1.7852505493164061,-1.7766757965087892,-1.768101043701172,-1.7595262908935547,-1.7509515380859375,-1.7423767852783203,-1.733802032470703,-1.7252272796630859,-1.7166525268554687,-1.7080777740478517,-1.6995030212402344,-1.6909282684326172,-1.682353515625,-1.6737787628173828,-1.6652040100097656,-1.6566292572021484,-1.6480545043945312,-1.6394797515869142,-1.630904998779297,-1.6223302459716797,-1.6137554931640625,-1.6051807403564453,-1.596605987548828,-1.5880312347412109,-1.5794564819335937,-1.5708817291259765,-1.5623069763183595,-1.5537322235107422,-1.545157470703125,-1.5365827178955078,-1.5280079650878906,-1.5194332122802734,-1.5108584594726562,-1.5022837066650392,-1.4937089538574218,-1.4851342010498048,-1.4765594482421875,-1.4679846954345703,-1.4594099426269531,-1.450835189819336,-1.4422604370117187,-1.4336856842041015,-1.4251109313964845,-1.4165361785888673,-1.40796142578125,-1.3993866729736328,-1.3908119201660156,-1.3822371673583984,-1.3736624145507812,-1.365087661743164,-1.3565129089355468,-1.3479381561279298,-1.3393634033203126,-1.3307886505126953,-1.3222138977050781,-1.313639144897461,-1.3050643920898437,-1.2964896392822265,-1.2879148864746095,-1.279340133666992,-1.270765380859375,-1.2621906280517579,-1.2536158752441406,-1.2450411224365234,-1.2364663696289062,-1.2278916168212892,-1.2193168640136718,-1.2107421112060548,-1.2021673583984374,-1.1935926055908204,-1.1850178527832032,-1.176443099975586,-1.1678683471679687,-1.1592935943603515,-1.1507188415527345,-1.142144088745117,-1.1335693359375,-1.1249945831298827,-1.1164198303222657,-1.1078450775146484,-1.0992703247070312,-1.090695571899414,-1.0821208190917968,-1.0735460662841798,-1.0649713134765624,-1.0563965606689454,-1.0478218078613282,-1.039247055053711,-1.0306723022460937,-1.0220975494384765,-1.0135227966308595,-1.004948043823242,-0.996373291015625,-0.9877985382080078,-0.9792237854003907,-0.9706490325927735,-0.9620742797851562,-0.953499526977539,-0.9449247741699218,-0.9363500213623047,-0.9277752685546875,-0.9192005157470703,-0.9106257629394531,-0.902051010131836,-0.8934762573242188,-0.8849015045166015,-0.8763267517089843,-0.8677519989013672,-0.85917724609375,-0.8506024932861328,-0.8420277404785156,-0.8334529876708985,-0.8248782348632813,-0.816303482055664,-0.8077287292480468,-0.7991539764404296,-0.7905792236328124,-0.7820044708251954,-0.7734297180175782,-0.764854965209961,-0.7562802124023438,-0.7477054595947266,-0.7391307067871093,-0.7305559539794921,-0.7219812011718749,-0.7134064483642577,-0.7048316955566407,-0.6962569427490235,-0.6876821899414063,-0.6791074371337891,-0.6705326843261719,-0.6619579315185546,-0.6533831787109374,-0.6448084259033202,-0.6362336730957032,-0.627658920288086,-0.6190841674804688,-0.6105094146728516,-0.6019346618652344,-0.5933599090576172,-0.5847851562499999,-0.5762104034423827,-0.5676356506347657,-0.5590608978271485,-0.5504861450195313,-0.5419113922119141,-0.5333366394042969,-0.5247618865966797,-0.5161871337890624,-0.5076123809814452,-0.499037628173828,-0.490462875366211,-0.4818881225585938,-0.4733133697509766,-0.4647386169433594,-0.45616386413574217,-0.44758911132812496,-0.43901435852050774,-0.4304396057128905,-0.42186485290527354,-0.4132901000976563,-0.4047153472900391,-0.3961405944824219,-0.3875658416748047,-0.37899108886718746,-0.3704 ...
